# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
order_data = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/data.tsv.txt',sep = '@')

# %%
order_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
sales_data = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/Sales Transactions-2017.csv')

# %%
sales_data
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
order_data.shape
# Out:
# (4622, 5)

# %%
sales_data.shape
# Out:
# (47290, 9)

# %%
order_data['choice_description'].nunique()
# Out:
# 1043

# %%
order_data['item_name'].value_counts().head()
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: count, dtype: int64

# %%
euro_df = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/Euro_2012_stats_TEAM.csv')

# %%
euro_df.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro_df[euro_df['Goals']<2]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 11  Republic of Ireland      1                7                12
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 11             36.8%             5.2%                          28
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 11             0              0                     0  ...          17
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 11                 65.4%         43             51        11             6
#
#     Red Cards  Subs on  Subs off  Players Used
# 11          1       10        10            17
#
# [1 rows x 35 columns]

# %%
euro_df[(euro_df['Yellow Cards']>5) | (euro_df['Red Cards']>3)]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 4                France      3               22                24
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# ...

# %%
euro_df[euro_df['Yellow Cards']< 2]
# Out:
# Empty DataFrame
# Columns: [Team, Goals, Shots on target, Shots off target, Shooting Accuracy, % Goals-to-shots, Total shots (inc. Blocked), Hit Woodwork, Penalty goals, Penalties not scored, Headed goals, Passes, Passes completed, Passing Accuracy, Touches, Crosses, Dribbles, Corners Taken, Tackles, Clearances, Interceptions, Clearances off line, Clean Sheets, Blocks, Goals conceded, Saves made, Saves-to-shots ratio, Fouls Won, Fouls Conceded, Offsides, Yellow Cards, Red Cards, Subs on, Subs off, Players Used]
# Index: []
#
# [0 rows x 35 columns]

# %%
euro_df[(euro_df['Goals']<2) & (euro_df['Yellow Cards']< 2)]
# Out:
# Empty DataFrame
# Columns: [Team, Goals, Shots on target, Shots off target, Shooting Accuracy, % Goals-to-shots, Total shots (inc. Blocked), Hit Woodwork, Penalty goals, Penalties not scored, Headed goals, Passes, Passes completed, Passing Accuracy, Touches, Crosses, Dribbles, Corners Taken, Tackles, Clearances, Interceptions, Clearances off line, Clean Sheets, Blocks, Goals conceded, Saves made, Saves-to-shots ratio, Fouls Won, Fouls Conceded, Offsides, Yellow Cards, Red Cards, Subs on, Subs off, Players Used]
# Index: []
#
# [0 rows x 35 columns]

# %%
euro_df.shape
# Out:
# (16, 35)

# %%
euro_df.isna().sum()
# Out:
# Team                          0
# Goals                         0
# Shots on target               0
# Shots off target              0
# Shooting Accuracy             0
# % Goals-to-shots              0
# Total shots (inc. Blocked)    0
# Hit Woodwork                  0
# Penalty goals                 0
# Penalties not scored          0
# Headed goals                  0
# Passes                        0
# Passes completed              0
# Passing Accuracy              0
# Touches                       0
# Crosses                       0
# Dribbles                      0
# Corners Taken                 0
# Tackles                       0
# Clearances                    0
# Interceptions                 0
# Clearances off line           1
# Clean Sheets                  0
# Blocks                        0
# Goals conceded                0
# Saves made                    0
# Saves-to-shots ratio          0
# Fouls Won                     0
# Fouls Conceded                0
# ...

# %%
euro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
euro_df['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 euro_
#
# NameError: name 'euro_' is not defined

# %%
euro_df['Goals']>5

# %%
euro_df[euro_df['Goals']>5]

# %%
euro_df['Shots on target']

# %%
euro_df[euro_df['Shots on target']<20]

# %%
euro_df[euro_df['Team']=='France']

# %%
euro_df.sort_values(by='Goals',ascending=False)

# %%
euro_df['Goals']>2

# %%
euro_df['Yellow Cards']<4

# %%
euro_df[(euro_df['Red Cards']>3) | (euro_df['Yellow Cards']>5)]

# %%
euro_df.iloc[0:10,0:5]

# %%
#dataframe conversion

# %%
learners = {'Name':['Akash','Gayathri','Sai','Praveen','Madesh'],'Batch':[2019,2020,2020,2019,2020]}

# %%
learners

# %%
learn_df = pd.DataFrame(learners)

# %%
learn_df

# %%
type(learn_df)

# %%
#Series

# %%
a = [10,20,30,40,50]

# %%
type(a)

# %%
b = pd.Series(a)

# %%
b

# %%
type(b)

# %%
student_df = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/student-mat.csv')

# %%
student_df

# %%
student_df.dtypes

# %%
student_df.isna().sum()

# %%
student_df['age']=student_df['age']+2

# %%
student_df['freetime']=student_df['freetime']+5

# %%
student_df

# %%
type(student_df['Mjob'])

# %%
student_df['Mjob'].str.upper()

# %%
def change(x):
    return x.upper()

# %%
student_df['Fjob'].apply(change)

# %%
student_df['Eligibility_Criteria'] = lambda x:1 if 'age'>18 else 0

# %%
student_df

# %%
insurance_df = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/insurance.csv')

# %%
insurance_df

# %%
insurance_df.groupby('region')['charges'].mean()

# %%
insurance_df.nunique()

# %%
pd.crosstab(insurance_df['sex'],insurance_df['smoker'])
