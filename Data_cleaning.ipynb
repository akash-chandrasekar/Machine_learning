# %%
import pandas as pd

# %%
sales_2017 = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/Sales Transactions-2017.csv')

# %%
sales_2018 = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/Sales Transactions-2018.csv')

# %%
sales_2019 = pd.read_csv('ProIT/Datasets/drive-download-20250707T061037Z-1-001/Sales Transactions-2019.csv')

# %%
sales_2017.head()
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
sales_2018.head()
# Out:
#        Date  Voucher Party            Product       Qty Rate     Gross Disc  \
# 0  1/4/2018  Sal:146  TP13  SILVER POUCH 9*12        50   85  4,250.00  NaN
# 1  1/4/2018  Sal:146  TP13             RUBBER         5  290  1,450.00  NaN
# 2  1/4/2018  Sal:146  TP13   DURGA 10*12 Blue  1,600.00  5.5  8,800.00  NaN
# 3  1/4/2018  Sal:146  TP13   DURGA 13*16 BLUE       400   11  4,400.00  NaN
# 4  1/4/2018  Sal:146  TP13    10*12 SARAS-NAT       600  8.1  4,860.00  NaN
#
#   Voucher Amount
# 0      66,724.00
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
sales_2019.head()
# Out:
#        Date  Voucher            Party         Product  Qty      Rate  \
# 0  1/4/2019  Sal:687  BALAJI PLASTICS   DONA-VAI-9100    1  1,730.00
# 1  1/4/2019  Sal:687  BALAJI PLASTICS  SMART BOUL(48)    1  1,730.00
# 2  1/4/2019  Sal:688  BALAJI PLASTICS      Vishnu Ice  110      18.5
# 3                                28/3                    0         0
# 4  1/4/2019  Sal:689  BALAJI PLASTICS     100LEAF -SP    3       585
#
#       Gross Disc Voucher Amount
# 0  1,730.00  NaN       3,460.00
# 1  1,730.00  NaN            NaN
# 2  2,035.00  NaN       2,035.00
# 3
# 4  1,755.00  NaN       1,755.00

# %%
sales_data = pd.concat([sales_2017,sales_2018,sales_2019])

# %%
sales_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_data.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
sales_data = sales_data.dropna(subset = 'Qty')

# %%
sales_data
# Out:
#              Date   Voucher               Party              Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100
# ...           ...       ...                 ...                  ...
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK
# 19174         NaN   Total                   NaN                  NaN
# 19175         NaN   Total                   NaN                  NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_data.isna().sum()
# Out:
# Date                 34
# Voucher               0
# Party                34
# Product              34
# Qty                   0
# Rate                  1
# Gross                 1
# Disc              93052
# Voucher Amount    71089
# dtype: int64

# %%
sales_data = sales_data.drop('Voucher Amount',axis = 1)

# %%
sales_data.isna().sum()
# Out:
# Date          34
# Voucher        0
# Party         34
# Product       34
# Qty            0
# Rate           1
# Gross          1
# Disc       93052
# dtype: int64

# %%
sales_data = sales_data.dropna(subset = 'Date' )

# %%
sales_data.isna().sum()
# Out:
# Date           0
# Voucher        0
# Party          0
# Product        0
# Qty            0
# Rate           1
# Gross          1
# Disc       93052
# dtype: int64

# %%
sales_data['Disc'] = sales_data['Disc'].fillna(0)

# %%
sales_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# Gross      1
# Disc       0
# dtype: int64

# %%
sales_data = sales_data.dropna()

# %%
sales_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# Gross      0
# Disc       0
# dtype: int64

# %%
sales_data.shape
# Out:
# (98614, 8)

# %%
sales = pd.read_csv('Sales_Data.csv')

# %%
sales
# Out:
#        Unnamed: 0        Date   Voucher               Party  \
# 0               0    1/4/2017     Sal:1    SOLANKI PLASTICS
# 1               1    1/4/2017     Sal:1    SOLANKI PLASTICS
# 2               2    1/4/2017     Sal:2  SARNESWARA TRADERS
# 3               3    1/4/2017     Sal:2  SARNESWARA TRADERS
# 4               4    1/4/2017     Sal:2  SARNESWARA TRADERS
# ...           ...         ...       ...                 ...
# 98609       19167  10/10/2019  Sal:4935           K.SRIHARI
# 98610       19168  10/10/2019  Sal:4935           K.SRIHARI
# 98611       19169  10/10/2019  Sal:4935           K.SRIHARI
# 98612       19170  10/10/2019  Sal:4935           K.SRIHARI
# 98613       19171  10/10/2019  Sal:4935           K.SRIHARI
#
#                    Product  Qty      Rate      Gross Disc
# 0            DONA-VAI-9100    2  1,690.00   3,380.00    0
# 1          LITE FOAM(1200)    6  1,620.00   9,720.00    0
# 2        VISHNU CHOTA WINE  500        23  11,500.00    0
# ...

# %%
sales['Rate'] = sales['Rate'].replace(",","",regex = True)

# %%
sales['Rate'] = sales['Rate'].replace(" ","",regex = True)

# %%
sales['Rate'] = pd.to_numeric(sales['Rate'])

# %%
sales.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Voucher        object
# Party          object
# Product        object
# Qty            object
# Rate          float64
# Gross          object
# Disc           object
# dtype: object

# %%
sales = sales.drop('Unnamed: 0',axis = 1)

# %%
sales
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 98609  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 98610  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 98611  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 98612  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 98613  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate      Gross Disc
# 0      1690.0   3,380.00    0
# ...

# %%
sales['Qty'] = sales['Qty'].replace(" ","",regex = True)

# %%
sales['Qty'] = sales['Qty'].replace(",","",regex = True)

# %%
sales['Rate'] = pd.to_numeric(sales['Qty'])

# %%
sales.dtypes
# Out:
# Date        object
# Voucher     object
# Party       object
# Product     object
# Qty         object
# Rate       float64
# Gross       object
# Disc        object
# dtype: object
